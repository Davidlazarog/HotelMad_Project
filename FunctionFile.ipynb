# %% [markdown]
# # Con estas tres funciones podremos sacar datos especificos

# %%
import pandas as pd
import numpy as np 
import re
import src.funcionesclean as op
import src.funcionesvol2 as po
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#Importamos los dos datasets
hotel = op.read('output/hotel_clean.csv')

# %% [markdown]
# ## FUNCION 1
# ### PINTAR LA NOTA MEDIA SEGUN EL PAIS POR MESES.
# #### Hay que pasarle uno de los 5 paises que estan en la siguiente celda

# %%
print(pd.unique(hotel['Hotel_Country']))
# Out:
# ['Netherlands' 'United Kingdom' 'France' 'Spain' 'Italy' 'Austria']

# %%
po.notamedia_pais_meses()
# Out:
# Introduce el pais : France

# %% [markdown]
# ## FUNCION 2
# ### NOTA MEDIA POR PAIS EN UN MES EN CONCRETO.
# #### Hay que pasarle uno de los 5 paises que estan en la siguiente celda y el mes que queramos mirar

# %%
print(pd.unique(hotel['Hotel_Country']))
print(pd.unique(hotel['Month']))
# Out:
# ['Netherlands' 'United Kingdom' 'France' 'Spain' 'Italy' 'Austria']
# ['08Agosto' '07Julio' '06Junio' '05Mayo' '04Abril' '03Marzo' '02Febrero'
#  '01Enero' '12Diciembre' '11Noviembre' '10Octubre' '09Septiembre']

# %%
po.media_paismes()
# Out:
# Introduce el pais : Netherlands
# Introduce el mes: 12Diciembre
#             Reviewer_Score
#                       mean
# Month
# 12Diciembre       8.609913

# %% [markdown]
# ## FUNCION 3
# ### Que de que nacionalidad son los clientes que mas importancia le dan a un tipo de review especifica en España.

# %%
hotel_esp = op.read('output/hotel_esp.csv')
print(pd.unique(hotel_esp['Negative_Review2']))
# Out:
# ['Aire Acondicionado' 'Comentario positivo' 'Suciedad' 'Antiguedad'
#  'Habitaciones' 'Utilities' 'Comidas']

# %%
po.reviewtop10()
# Out:
# Introduce el tipo de queja: Comidas
#                           Reviewer_Score
# Reviewer_Nationality
# United Kingdom                      1038
# United States of America             220
# Ireland                              117
# Australia                             93
# Spain                                 70
# Netherlands                           69
# Israel                                67
# Germany                               65
# United Arab Emirates                  62
# Canada                                60
